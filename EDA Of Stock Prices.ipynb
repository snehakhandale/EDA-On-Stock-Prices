# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BAC.csv')

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2006-01-03  46.919998  47.180000  46.150002  47.080002  34.811729
# 1     2006-01-04  47.000000  47.240002  46.450001  46.580002  34.442013
# 2     2006-01-05  46.580002  46.830002  46.320000  46.639999  34.486385
# 3     2006-01-06  46.799999  46.910000  46.349998  46.570000  34.434616
# 4     2006-01-09  46.720001  46.970001  46.360001  46.599998  34.456806
# ...          ...        ...        ...        ...        ...        ...
# 3518  2019-12-24  35.189999  35.279999  35.119999  35.220001  34.513897
# 3519  2019-12-26  35.320000  35.560001  35.290001  35.520000  34.807880
# 3520  2019-12-27  35.700001  35.720001  35.259998  35.349998  34.641285
# 3521  2019-12-30  35.570000  35.650002  35.090000  35.150002  34.445301
# 3522  2019-12-31  35.029999  35.259998  34.970001  35.220001  34.513897
#
#         Volume
# 0     16296700
# 1     17757900
# 2     14970700
# 3     12599800
# 4     15619400
# ...

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2006-01-03  46.919998  47.180000  46.150002  47.080002  34.811729  16296700
# 1  2006-01-04  47.000000  47.240002  46.450001  46.580002  34.442013  17757900
# 2  2006-01-05  46.580002  46.830002  46.320000  46.639999  34.486385  14970700
# 3  2006-01-06  46.799999  46.910000  46.349998  46.570000  34.434616  12599800
# 4  2006-01-09  46.720001  46.970001  46.360001  46.599998  34.456806  15619400

# %%
df.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3518  2019-12-24  35.189999  35.279999  35.119999  35.220001  34.513897
# 3519  2019-12-26  35.320000  35.560001  35.290001  35.520000  34.807880
# 3520  2019-12-27  35.700001  35.720001  35.259998  35.349998  34.641285
# 3521  2019-12-30  35.570000  35.650002  35.090000  35.150002  34.445301
# 3522  2019-12-31  35.029999  35.259998  34.970001  35.220001  34.513897
#
#         Volume
# 3518  13805400
# 3519  26992100
# 3520  28111300
# 3521  30705100
# 3522  29630100

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3523.000000  3523.000000  3523.000000  3523.000000  3523.000000
# mean     22.957905    23.220247    22.669631    22.938135    19.851501
# std      13.409170    13.492552    13.321380    13.410517    10.426581
# min       3.220000     3.510000     2.530000     3.140000     2.759305
# 25%      13.620000    13.790000    13.395000    13.560000    12.181610
# 50%      16.980000    17.150000    16.760000    16.950001    15.180848
# 75%      29.915000    30.185001    29.540001    29.875000    28.225653
# max      55.040001    55.080002    54.820000    54.900002    42.099216
#
#              Volume
# count  3.523000e+03
# mean   1.174800e+08
# std    1.130062e+08
# min    4.835400e+06
# 25%    5.063375e+07
# 50%    8.519980e+07
# 75%    1.468264e+08
# max    1.226791e+09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3523 entries, 0 to 3522
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3523 non-null   object
#  1   Open       3523 non-null   float64
#  2   High       3523 non-null   float64
#  3   Low        3523 non-null   float64
#  4   Close      3523 non-null   float64
#  5   Adj Close  3523 non-null   float64
#  6   Volume     3523 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 192.8+ KB

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0      2006-01-03
# 1      2006-01-04
# 2      2006-01-05
# 3      2006-01-06
# 4      2006-01-09
#           ...
# 3518   2019-12-24
# 3519   2019-12-26
# 3520   2019-12-27
# 3521   2019-12-30
# 3522   2019-12-31
# Name: Date, Length: 3523, dtype: datetime64[ns]

# %%
# Calculate the difference between 'Close' and 'Open' to determine the days where 'Close' > 'Open'

# %%
df['Close_Open_Diff'] = df['Close'] - df['Open']
df['Close_Open_Diff']
# Out:
# 0       0.160004
# 1      -0.419998
# 2       0.059997
# 3      -0.229999
# 4      -0.120003
#           ...
# 3518    0.030002
# 3519    0.200000
# 3520   -0.350003
# 3521   -0.419998
# 3522    0.190002
# Name: Close_Open_Diff, Length: 3523, dtype: float64

# %%
# Calculate the difference between 'High' and 'Low' for date-wise analysis
df['High_Low_Diff'] = df['High'] - df['Low']
df['High_Low_Diff']
# Out:
# 0       1.029998
# 1       0.790001
# 2       0.510002
# 3       0.560002
# 4       0.610000
#           ...
# 3518    0.160000
# 3519    0.270000
# 3520    0.460003
# 3521    0.560002
# 3522    0.289997
# Name: High_Low_Diff, Length: 3523, dtype: float64

# %%
# 1. Date wise analysis with high and low comparison

plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['High'], label='High')
plt.plot(df['Date'], df['Low'], label='Low')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Date wise analysis - High vs Low')
plt.legend()
plt.show()

# %%
#2. Days where Close > Open:
plt.figure(figsize=(8, 6))
df['Close_Open_Diff'].apply(lambda x: 1 if x > 0 else 0).value_counts().plot(kind='bar')
plt.title('Days where Close > Open')
plt.xlabel('Close > Open')
plt.ylabel('Count')
plt.xticks([0, 1], ['False', 'True'], rotation=0)
plt.show()

# %%
#3. Volume related to high/low:
plt.figure(figsize=(8, 6))
plt.scatter(df['Volume'], df['High'], label='High')
plt.scatter(df['Volume'], df['Low'], label='Low')
plt.xlabel('Volume')
plt.ylabel('Price')
plt.title('Volume related to High/Low')
plt.legend()
plt.show()

# %%
#3. Stock opening duration:
plt.figure(figsize=(8, 6))
df['Close_Open_Diff'].plot(kind='hist', bins=20)
plt.title('Stock Opening Duration Distribution')
plt.xlabel('Duration (Close - Open)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Close'], label='Close')
plt.plot(df['Date'], df['Adj Close'], label='Adj Close')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Close vs Adj-Close Prices Over Time')
plt.legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.show()
